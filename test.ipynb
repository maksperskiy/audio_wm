# %%
from inject import Injector
from extract import Extractor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from inject import Injector
# ----> 2 from extract import Exctractor
#
# ImportError: cannot import name 'Exctractor' from 'extract' (/home/INTEXSOFT/maksim.stupakevich/work/audio_cls/extract.py)

# %%
injector = Injector()
exctractor = Exctractor()

# %%
injector.process("int.wav")
# Out:
# Count = 317
# Max count = 642
# Quality = 0.4937694704049844
# SNR = 28.135406870828508

# %%
exctractor.process("injected_out.wav")
